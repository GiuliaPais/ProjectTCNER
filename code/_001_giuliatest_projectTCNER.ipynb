# %%
# !pip install -U kaleido
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
from google.colab import drive
drive.mount('/gdrive')

project_folder = '/gdrive/MyDrive/ProjectTCNER'
# Out:
# Mounted at /gdrive

# %%
import os
import pandas as pd
import plotly.express as px

data_folder = os.path.join(project_folder, "data")
trainset_file = os.path.join(data_folder, "DBLPTrainset.txt")
testset_file = os.path.join(data_folder, "DBLPTestset.txt")
ground_truth_file = os.path.join(data_folder, "DBLPTestGroundTruth.txt")

# %%
out_folder = os.path.join(project_folder, "out")

# %%
dataset_train = pd.read_table(os.path.join(trainset_file), sep="\t", header=None, names=['y', 'X'],
                              index_col=0)
dataset_train
# Out:
#               y                                                  X
# 0         ISCAS  Scalable Serial-parallel Multiplier over GF(2m...
# 1      SIGGRAPH                                Plenoptic sampling.
# 2         ISCAS  Sensitivity and uniformity of a 0.18micrometer...
# 3           WWW      A survey of web archive search architectures.
# 4         ISCAS  Understanding dynamic behavior of mm-wave CML ...
# ...         ...                                                ...
# 21638     ISCAS  Decoding a Family of Dense Codes using the Sum...
# 21639      VLDB  CoHadoop: Flexible Data Placement and Its Expl...
# 21640     ISCAS  Full system simulation with QEMU: An approach ...
# 21641   INFOCOM  Localization in non-localizable sensor and ad-...
# 21642   INFOCOM  Topology Control of Multihop Wireless Networks...
#
# [21643 rows x 2 columns]

# %%
dataset_test = pd.read_table(os.path.join(testset_file), sep="\t", header=None, names=['X'],
                              index_col=0)
dataset_test
# Out:
#                                                       X
# 0      Fast recursive adaptation for nonlinear filters.
# 1     High-Throughput Data Compressor Designs Using ...
# 2     Functional Verification of ECL Circuits Includ...
# 3     Efficient network generation under general pre...
# 4     Creating the earth as a backdrop in <i>Gravity...
# ...                                                 ...
# 3368         GEM: A Geometric Algorithm for Scheduling.
# 3369  On the geographic patterns of a large-scale mo...
# 3370  NScale: Neighborhood-centric Analytics on Larg...
# 3371  Sufficient Conditions for Finding Multiple Ope...
# 3372  Folksonomy based socially-aware recommendation...
#
# [3373 rows x 1 columns]

# %%
dataset_gt = pd.read_table(os.path.join(ground_truth_file), sep="\t", header=None, names=['y'],
                              index_col=0)
dataset_gt
# Out:
#              y
# 0        ISCAS
# 1        ISCAS
# 2        ISCAS
# 3          WWW
# 4     SIGGRAPH
# ...        ...
# 3368     ISCAS
# 3369   INFOCOM
# 3370      VLDB
# 3371     ISCAS
# 3372       WWW
#
# [3373 rows x 1 columns]

# %%
dataset_test = pd.merge(dataset_test, dataset_gt, left_index=True, right_index=True)
dataset_test
# Out:
#                                                       X         y
# 0      Fast recursive adaptation for nonlinear filters.     ISCAS
# 1     High-Throughput Data Compressor Designs Using ...     ISCAS
# 2     Functional Verification of ECL Circuits Includ...     ISCAS
# 3     Efficient network generation under general pre...       WWW
# 4     Creating the earth as a backdrop in <i>Gravity...  SIGGRAPH
# ...                                                 ...       ...
# 3368         GEM: A Geometric Algorithm for Scheduling.     ISCAS
# 3369  On the geographic patterns of a large-scale mo...   INFOCOM
# 3370  NScale: Neighborhood-centric Analytics on Larg...      VLDB
# 3371  Sufficient Conditions for Finding Multiple Ope...     ISCAS
# 3372  Folksonomy based socially-aware recommendation...       WWW
#
# [3373 rows x 2 columns]

# %%
dataset_whole = pd.concat([dataset_train, dataset_test])
dataset_whole
# Out:
#              y                                                  X
# 0        ISCAS  Scalable Serial-parallel Multiplier over GF(2m...
# 1     SIGGRAPH                                Plenoptic sampling.
# 2        ISCAS  Sensitivity and uniformity of a 0.18micrometer...
# 3          WWW      A survey of web archive search architectures.
# 4        ISCAS  Understanding dynamic behavior of mm-wave CML ...
# ...        ...                                                ...
# 3368     ISCAS         GEM: A Geometric Algorithm for Scheduling.
# 3369   INFOCOM  On the geographic patterns of a large-scale mo...
# 3370      VLDB  NScale: Neighborhood-centric Analytics on Larg...
# 3371     ISCAS  Sufficient Conditions for Finding Multiple Ope...
# 3372       WWW  Folksonomy based socially-aware recommendation...
#
# [25016 rows x 2 columns]

# %% [markdown]
# Check for missing values

# %%
dataset_whole.isna().any()
# Out:
# y    False
# X    False
# dtype: bool

# %% [markdown]
# Inspect categories

# %%
cat_freq = px.histogram(
    dataset_train,
    x='y',
    template='simple_white',
    color_discrete_sequence=['#397d5a'])
cat_freq.update_layout(
    title={
        'text': 'Number of samples per category'.upper(),
        'x': 0.5,
        'font': {
            'size': 30
        }
    },
    font={
        'family': 'Barlow, sans-serif',
        'size': 16
    },
    yaxis_title='COUNT',
    xaxis_title='',
    width=500*2,
    height=400*2
)
cat_freq.update_xaxes(
    categoryorder='total ascending'
)
cat_freq.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8152c3d4-a182-4e13-a3ad-3c542fed49bd" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8152c3d4-a182-4e13-a3ad-3c542fed49bd")) {                    Plotly.newPlot(                        "8152c3d4-a182-4e13-a3ad-3c542fed49bd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"y=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#397d5a","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["ISCAS","SIGGRAPH","ISCAS","WWW","ISCAS","SIGGRAPH","INFOCOM","ISCAS","ISCAS","ISCAS","ISCAS","ISCAS","ISCAS","ISCAS","WWW","SIGGRAPH","ISCAS","INFOCOM","ISCAS","VLDB","SIGGRAPH","WWW","SIGGRAPH","VLDB","ISCAS","VLDB","VLDB","ISCAS","WWW","ISCAS","INFOCOM","VLDB","SIGGRAPH","ISCAS","INFOCOM","ISCAS","VLDB","WWW","INFOCOM","SIGGRAPH","SIGGRAPH","INFOCOM","VLDB","VLDB","VLDB","SIGGRAPH","INFOCOM","INFOCOM","WWW","INFOCOM","WWW","INFOCOM","INFOCOM","INFOCOM","ISCAS","VLDB","ISCAS","SIGGRAPH","ISCAS","SIGGRAPH","WWW","ISCAS","VLDB","VLDB","ISCAS","SIGGRAPH","INFOCOM","VLDB","ISCAS","VLDB","SIGGRAPH","INFOCOM","ISCAS","WWW","ISCAS","VLDB","ISCAS","ISCAS","ISCAS","VLDB","VLDB","ISCAS","SIGGRAPH","VLDB","ISCAS","WWW","WWW","ISCAS","ISCAS","INFOCOM","ISCAS","ISCAS","ISCAS","INFOCOM","WWW","ISCAS","WWW","VLDB","WWW","INFOCOM","WWW","INFOCOM","SIGGRAPH","ISCAS","VLDB","WWW","VLDB","WWW","SIGGRAPH","VLDB","WWW","VLDB","ISCAS","VLDB","WWW","ISCAS","ISCAS","SIGGRAPH","WWW","ISCAS","ISCA
# %%
cat_freq.write_image(file=os.path.join(out_folder, 'category_count.jpg'), scale=2)

# %%
info_df = dataset_train
info_df['text_length'] = info_df.X.str.len()
info_df['text_words'] = info_df.X.str.split().apply(lambda x: len(x))
info_df = pd.melt(info_df, id_vars=['X', 'y'], var_name='type', value_name='val')

# %%
shortest_lengths = info_df.loc[info_df['val'] <= 2].sort_values('val')
shortest_lengths
# Out:
#                                X         y        type  val
# 33586                    Oxygen.  SIGGRAPH  text_words    1
# 27975                  Sponsors.      VLDB  text_words    1
# 27097              Wake-on-WLAN.       WWW  text_words    1
# 36793                Oneironaut.  SIGGRAPH  text_words    1
# 26996                  Tengible.  SIGGRAPH  text_words    1
# ...                          ...       ...         ...  ...
# 32245         Database Machines.      VLDB  text_words    2
# 32246                  Cloud 21.  SIGGRAPH  text_words    2
# 32296      Schema Summarization.      VLDB  text_words    2
# 30878            Constraint SVG.       WWW  text_words    2
# 43197  Topic-sensitive PageRank.       WWW  text_words    2
#
# [281 rows x 4 columns]

# %%
lengths_distrib_plot = px.box(info_df, x='y', y='val',
                              color='type',
                              points='all',
                              facet_row='type',
                              template='gridon'
                              )
lengths_distrib_plot.update_layout(
    height=800,
    showlegend=False,
    font={
        'family': 'Barlow, sans-serif',
        'size': 16
    },
    title=dict(
        text='Distribution of lengths per category',
        x=0.5,
        font=dict(size=30)
    )
)
lengths_distrib_plot.update_yaxes(
    matches=None
)
lengths_distrib_plot.for_each_yaxis(lambda axis: axis.update(showline=True,
                                                             mirror=True))
lengths_distrib_plot.for_each_yaxis(lambda axis: axis.update(
    title='Number of characters', range=[0, 250]),
    row=2)
lengths_distrib_plot.for_each_yaxis(
    lambda axis: axis.update(title='Number of words', range=[0, 35]),
    row=1)
lengths_distrib_plot.update_xaxes(
    title=''
)
lengths_distrib_plot.for_each_xaxis(lambda axis: axis.update(showline=True,
                                                             mirror=True))
lengths_distrib_plot.for_each_annotation(lambda a: a.update(text=''))
lengths_distrib_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e185c480-bb49-4853-9fc1-554d7e71f5fd" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e185c480-bb49-4853-9fc1-554d7e71f5fd")) {                    Plotly.newPlot(                        "e185c480-bb49-4853-9fc1-554d7e71f5fd",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"type=text_length\u003cbr\u003ey=%{x}\u003cbr\u003eval=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"text_length","marker":{"color":"#1F77B4"},"name":"text_length","notched":false,"offsetgroup":"text_length","orientation":"v","showlegend":true,"x":["ISCAS","SIGGRAPH","ISCAS","WWW","ISCAS","SIGGRAPH","INFOCOM","ISCAS","ISCAS","ISCAS","ISCAS","ISCAS","ISCAS","ISCAS","WWW","SIGGRAPH","ISCAS","INFOCOM","ISCAS","VLDB","SIGGRAPH","WWW","SIGGRAPH","VLDB","ISCAS","VLDB","VLDB","ISCAS","WWW","ISCAS","INFOCOM","VLDB","SIGGRAPH","ISCAS","INFOCOM","ISCAS","VLDB","WWW","INFOCOM","SIGGRAPH","SIGGRAPH","INFOCOM","VLDB","VLDB","VLDB","SIGGRAPH","INFOCOM","INFOCOM","WWW","INFOCOM","WWW","INFOCOM","INFOCOM","INFOCOM","IS
APH","ISCAS","ISCAS","WWW","INFOCOM","SIGGRAPH","WWW","INFOCOM","ISCAS","INFOCOM","WWW","VLDB","INFOCOM","INFOCOM","INFOCOM","VLDB","VLDB","WWW","VLDB","INFOCOM","VLDB","ISCAS","ISCAS","WWW","ISCAS","ISCAS","INFOCOM","WWW","ISCAS","WWW","INFOCOM","ISCAS","ISCAS","WWW","INFOCOM","VLDB","VLDB","ISCAS","ISCAS","ISCAS","VLDB","ISCAS","INFOCOM","ISCAS","VLDB","ISCAS","ISCAS","WWW","ISCAS","ISCAS","INFOCOM","ISCAS","ISCAS","INFOCOM","SIGGRAPH","ISCAS","INFOCOM","INFOCOM","VLDB","ISCAS","SIGGRAPH","ISCAS","ISCAS","INFOCOM", ...

# %%
lengths_distrib_plot.write_image(file=os.path.join(out_folder, 'lengths_distrib.jpg'), scale=2)

# %%
next(info_df.iterrows())
# Out:
# (0,
#  X       Scalable Serial-parallel Multiplier over GF(2m...
#  y                                                   ISCAS
#  type                                          text_length
#  val                                                   102
#  Name: 0, dtype: object)

# %%
from collections import Counter

word_freqs = Counter()

for _, row in info_df.iterrows():
  text = row['X']
  words = text.split()
  word_freqs.update(words)

word_freqs_df = pd.DataFrame.from_dict(word_freqs, orient='index', columns=['count'])
word_freqs_df.sort_values(by='count', inplace=True)

# %%
word_freq_plot_most_uncommon = px.bar(word_freqs_df.iloc[:30], x='count',
                        y=word_freqs_df.iloc[:30].index, orientation='h')
word_freq_plot_most_uncommon.update_layout(
    margin=dict(l=20, r=20, t=20, b=20),
    height=750
)
word_freq_plot_most_uncommon.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="efe36dce-6483-41bc-9ac0-5ab7a290d9ac" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efe36dce-6483-41bc-9ac0-5ab7a290d9ac")) {                    Plotly.newPlot(                        "efe36dce-6483-41bc-9ac0-5ab7a290d9ac",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2],"xaxis":"x","y":["POSA:","dropping-based","Subspaces.","Decisive","Catching","color-space","droplet","ETSPC","130&micro;W","immersion","contested","multiprocessing","performer:","M\u002fM\u002f1","IRIS","medium-term","group's","NTT","NTT's","human-centered","polarization-analyzing","quora.","Wisdom","2-6GHz","ASPA2","multi-threshold","re-pairing","DBMS-like","AAN's","Algortihm."],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...

# %%
word_freq_plot_most_common = px.bar(word_freqs_df.iloc[-30:], x='count',
                        y=word_freqs_df.iloc[-30:].index, orientation='h')
word_freq_plot_most_common.update_layout(
    margin=dict(l=20, r=20, t=20, b=20),
    height=750
)
word_freq_plot_most_common.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47fe3094-0949-4795-9ded-8d00afcb33d1" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47fe3094-0949-4795-9ded-8d00afcb33d1")) {                    Plotly.newPlot(                        "47fe3094-0949-4795-9ded-8d00afcb33d1",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[878,918,1006,1072,1094,1106,1122,1138,1166,1256,1322,1346,1346,1432,1596,1856,1860,1928,2050,2702,3078,3554,4676,5616,6038,8774,10176,10200,13628,17798],"xaxis":"x","y":["data","power","by","wireless","Using","an","from","Efficient","On","Design","Wireless","CMOS","The","web","networks.","Data","based","Networks.","An","using","to","on","a","with","the","A","in","and","of","for"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorba ...
